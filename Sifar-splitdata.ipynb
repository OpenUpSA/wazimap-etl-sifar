# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\USER\Desktop\OpenUP\Sifar_V2\Organisations\organisationEDITED.csv')
df
# Out:
#                                     Name  \
# 0                    Dr Hannelie Joubert
# 1                     Dr Richard Dunning
# 2                  Dr Gretha Van Heerden
# 3                          Dr P P Maleka
# 4                Dr Francois De Villiers
# ...                                  ...
# 48881                     Dr S C Masondo
# 48882                     Dr S C Masondo
# 48883               Mr Sithembiso Khwela
# 48884  Dr Megan Schultz Psychiatrist Inc
# 48885            Dr Ralph Anthony Allden
#
#                                                  Address       Telephone  \
# 0      12 Stapelberg Avenue, East Lynne, Pretoria, Ga...  (012) 800 1178
# 1      Shop 19  New Salt Rock City, 1 Salt Rock Road,...  (032) 946 1311
# 2      1  Lelane, 14 Cathcart Road, Humewood, Gqeberh...  (083) 291 5897
# 3      502 Zone A, Lebowakgomo, Lepelle-Nkumpi Rural,...  (015) 632 4269
# 4      6 Hugo Naude Street, Jansendal, Uitenhage, Eas...  (041) 992 2299
# ...

# %%
df['Service'].unique()
# Out:
# array(['Family Medicine', 'General Practice (GP)', 'Clinics - Private',
#        'Psychiatry', 'Dentistry', 'Ophthalmology',
#        'Psychiatry (Neuropsychiatry)', nan, 'Physiotherapy',
#        'Optometry Practice', 'Physician Practice (Geriatric Medicine)',
#        'Biokinetics', 'Hospitals - Private',
#        'Psychiatric & Psychological - Clinics', 'Occupational Therapy',
#        'Psychology - Counselling', 'Registered Counsellor',
#        'Psychology - Clinical', 'Podiatry', 'Orthoptics',
#        'Speech Therapy & Audiology', 'Speech Therapy', 'Audiology',
#        'Psychology - Educational', 'Hearing Aid Acoustics', 'Dietetics',
#        'Psychology - Industrial', 'Psychology', 'Psychology - Research',
#        'Psychology - Neuro', 'Orthotics & Prosthetics', 'Home Based Care',
#        'Aged - Accommodation', 'Social Work', 'Community Dentistry',
#        'Aged - Clinics', 'Pharmacies - Retail',
#        'The Physically Disabled - Accommodation', 'Aged - Information',
# ...

# %%
myservice = ['Family Medicine', 'General Practice (GP)', 'Clinics - Private',
       'Psychiatry', 'Dentistry', 'Ophthalmology',
       'Psychiatry (Neuropsychiatry)','Physiotherapy',
       'Optometry Practice', 'Physician Practice (Geriatric Medicine)',
       'Biokinetics', 'Hospitals - Private',
       'Psychiatric & Psychological - Clinics', 'Occupational Therapy',
       'Psychology - Counselling', 'Registered Counsellor',
       'Psychology - Clinical', 'Podiatry', 'Orthoptics',
       'Speech Therapy & Audiology', 'Speech Therapy', 'Audiology',
       'Psychology - Educational', 'Hearing Aid Acoustics', 'Dietetics',
       'Psychology - Industrial', 'Psychology', 'Psychology - Research',
       'Psychology - Neuro', 'Orthotics & Prosthetics', 'Home Based Care',
       'Aged - Accommodation', 'Social Work', 'Community Dentistry',
       'Aged - Clinics', 'Pharmacies - Retail',
       'The Physically Disabled - Accommodation', 'Aged - Information',
       'Aged - Social Activity Centres', 'Aged - Support',
       'The Hearing Impaired - Information',
       'The Mentally Disabled - Accommodation',
       'The Physically Disabled - Clinics',
       'The Visually Impaired - Information', 'NGO or NPO',
       'Psychiatry (Geriatric Psychiatry)', 'Oral Hygiene']
for service in myservice:
    df1 = df.loc[df['Service'] == service]
    filename = 'V2_'+service +'.csv'
    print(filename)
    df1.to_csv(filename, index = False)
# Out:
# V2_Family Medicine.csv
# V2_General Practice (GP).csv
# V2_Clinics - Private.csv
# V2_Psychiatry.csv
# V2_Dentistry.csv
# V2_Ophthalmology.csv
# V2_Psychiatry (Neuropsychiatry).csv
# V2_Physiotherapy.csv
# V2_Optometry Practice.csv
# V2_Physician Practice (Geriatric Medicine).csv
# V2_Biokinetics.csv
# V2_Hospitals - Private.csv
# V2_Psychiatric & Psychological - Clinics.csv
# V2_Occupational Therapy.csv
# V2_Psychology - Counselling.csv
# V2_Registered Counsellor.csv
# V2_Psychology - Clinical.csv
# V2_Podiatry.csv
# V2_Orthoptics.csv
# V2_Speech Therapy & Audiology.csv
# V2_Speech Therapy.csv
# V2_Audiology.csv
# V2_Psychology - Educational.csv
# V2_Hearing Aid Acoustics.csv
# V2_Dietetics.csv
# V2_Psychology - Industrial.csv
# V2_Psychology.csv
# V2_Psychology - Research.csv
# V2_Psychology - Neuro.csv
# V2_Orthotics & Prosthetics.csv
# V2_Home Based Care.csv
# V2_Aged - Accommodation.csv
# V2_Social Work.csv
# V2_Community Dentistry.csv
# V2_Aged - Clinics.csv
# ...

# %%
for service in df['Service'].unique():
    count = df.loc[df['Service'] == service].count()
    filename = service +'.csv'
    print(filename)
    print(count)
# Out:
# Family Physician.csv
# Name         766
# Address      766
# Telephone    766
# Service      766
# Latitude     766
# Longitude    766
# dtype: int64
# General Practitioner (GP).csv
# Name         12601
# Address      12601
# Telephone    12601
# Service      12601
# Latitude     12601
# Longitude    12601
# dtype: int64
# Psychiatrist.csv
# Name         645
# Address      645
# Telephone    645
# Service      645
# Latitude     645
# Longitude    645
# dtype: int64
# Dentist.csv
# Name         3864
# Address      3864
# Telephone    3864
# Service      3864
# Latitude     3864
# Longitude    3864
# dtype: int64
# Ophthalmologist.csv
# Name         440
# Address      440
# Telephone    440
# Service      440
# Latitude     440
# Longitude    440
# dtype: int64
# Psychiatrist (Neuropsychiatrist).csv
# Name         12
# Address      12
# Telephone    12
# Service      12
# Latitude     12
# Longitude    12
# dtype: int64
# Community Dentist.csv
# Name         7
# Address      7
# ...
